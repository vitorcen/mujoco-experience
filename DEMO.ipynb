# %% [markdown]
# # MuJoCo 演示指南
#
# 本指南介绍如何运行 MuJoCo 的各种演示和示例。
#
# > **前提条件**：
# > 1. 已完成项目构建（运行 `./build.sh`）。
# > 2. 以下所有命令均假设你在项目根目录 `mujoco-experience/` 下执行。
# > 3. 第三方模型需要初始化 submodule: `git submodule update --init dependencies/mujoco_menagerie`
#
# ---
#
# ## 1. C++ 示例 (Simulate)
#
# `simulate` 是 MuJoCo 的主要可视化工具，支持加载 XML 模型、交互式拖拽、查看物理参数等。
#
# ### 常用操作键位
# - **鼠标左键拖拽**: 对物体施加外力
# - **鼠标右键拖拽**: 旋转视角
# - **Scroll**: 缩放视角
# - **Space**: 暂停/继续仿真
# - **Backspace**: 重置仿真
# - **Double Click**: 选择物体 (查看详细信息)
# - **F1**: 查看帮助菜单
#
# ---
#
# ## 2. 第三方机器人 (MuJoCo Menagerie)
#
# [MuJoCo Menagerie](https://github.com/google-deepmind/mujoco_menagerie) 是官方维护的高质量机器人模型库。
# 以下示例加载的是 `scene.xml`，通常包含地面 and 环境光照，适合直接观察。
#
# ### 🦿 四足机器人 (Quadrupeds)
#
# **Unitree Go1** (宇树科技)
#
# 📂 [`./dependencies/mujoco_menagerie/unitree_go1/scene.xml`](./dependencies/mujoco_menagerie/unitree_go1/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/unitree_go1/scene.xml

# %% [markdown]
# **Unitree Go2** (宇树科技)
#
# 📂 [`./dependencies/mujoco_menagerie/unitree_go2/scene.xml`](./dependencies/mujoco_menagerie/unitree_go2/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/unitree_go2/scene.xml

# %% [markdown]
# **ANYbotics ANYmal C**
#
# 📂 [`./dependencies/mujoco_menagerie/anybotics_anymal_c/scene.xml`](./dependencies/mujoco_menagerie/anybotics_anymal_c/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/anybotics_anymal_c/scene.xml

# %% [markdown]
# **Boston Dynamics Spot**
#
# 📂 [`./dependencies/mujoco_menagerie/boston_dynamics_spot/scene.xml`](./dependencies/mujoco_menagerie/boston_dynamics_spot/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/boston_dynamics_spot/scene.xml

# %% [markdown]
# ### 🦾 机械臂 (Manipulators)
#
# **Franka Emika Panda**
#
# 📂 [`./dependencies/mujoco_menagerie/franka_emika_panda/scene.xml`](./dependencies/mujoco_menagerie/franka_emika_panda/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/franka_emika_panda/scene.xml

# %% [markdown]
# **Universal Robots UR5e**
#
# 📂 [`./dependencies/mujoco_menagerie/universal_robots_ur5e/scene.xml`](./dependencies/mujoco_menagerie/universal_robots_ur5e/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/universal_robots_ur5e/scene.xml

# %% [markdown]
# **KUKA IIWA 14**
#
# 📂 [`./dependencies/mujoco_menagerie/kuka_iiwa_14/scene.xml`](./dependencies/mujoco_menagerie/kuka_iiwa_14/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/kuka_iiwa_14/scene.xml

# %% [markdown]
# **xArm 7** (UFactory)
#
# 📂 [`./dependencies/mujoco_menagerie/ufactory_xarm7/scene.xml`](./dependencies/mujoco_menagerie/ufactory_xarm7/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/ufactory_xarm7/scene.xml

# %% [markdown]
# **SO-101 / SO-ARM100** (Robot Studio)
#
# 开源 3D 打印机械臂。Hugging Face 的 PI05 VLA 模型常在此机械臂上进行微调。
#
# 📂 [`./dependencies/mujoco_menagerie/trs_so_arm100/scene.xml`](./dependencies/mujoco_menagerie/trs_so_arm100/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/trs_so_arm100/scene.xml

# %% [markdown]
# ### 🤖 人形机器人 (Humanoids)
#
# **Unitree H1**
#
# 📂 [`./dependencies/mujoco_menagerie/unitree_h1/scene.xml`](./dependencies/mujoco_menagerie/unitree_h1/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/unitree_h1/scene.xml

# %% [markdown]
# **Unitree G1**
#
# 📂 [`./dependencies/mujoco_menagerie/unitree_g1/scene.xml`](./dependencies/mujoco_menagerie/unitree_g1/scene.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/unitree_g1/scene.xml

# %% [markdown]
# ### 🖐️ 灵巧手 (Dexterous Hands)
#
# **Shadow Hand**
#
# 📂 [`./dependencies/mujoco_menagerie/shadow_hand/left_hand.xml`](./dependencies/mujoco_menagerie/shadow_hand/left_hand.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/shadow_hand/left_hand.xml

# %% [markdown]
# **Wonik Allegro Hand**
#
# 📂 [`./dependencies/mujoco_menagerie/wonik_allegro/scene_right.xml`](./dependencies/mujoco_menagerie/wonik_allegro/scene_right.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco_menagerie/wonik_allegro/scene_right.xml

# %% [markdown]
# ---
#
# ## 3. 内置模型运行清单
#
# MuJoCo 提供了丰富的内置模型，以下是可直接复制运行的命令：
#
# ### 🤖 机器人与载具 (Robots & Vehicles)
#
# **经典人形机器人 (Humanoid)**
#
# 📂 [`./dependencies/mujoco/model/humanoid/humanoid.xml`](./dependencies/mujoco/model/humanoid/humanoid.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/humanoid/humanoid.xml

# %% [markdown]
# **简易小车 (Car)**
#
# 📂 [`./dependencies/mujoco/model/car/car.xml`](./dependencies/mujoco/model/car/car.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/car/car.xml

# %% [markdown]
# **肌腱驱动机械臂 (Tendon Arm)**
#
# 📂 [`./dependencies/mujoco/model/tendon_arm/arm26.xml`](./dependencies/mujoco/model/tendon_arm/arm26.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/tendon_arm/arm26.xml

# %% [markdown]
# **滑块曲柄机构 (Slider Crank)**
#
# 📂 [`./dependencies/mujoco/model/slider_crank/slider_crank.xml`](./dependencies/mujoco/model/slider_crank/slider_crank.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/slider_crank/slider_crank.xml

# %% [markdown]
# ### 🧶 软体与布料 (Soft Bodies & Cloth)
#
# **飘动的旗帜 (Flag)**
#
# 📂 [`./dependencies/mujoco/model/flex/flag.xml`](./dependencies/mujoco/model/flex/flag.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/flex/flag.xml

# %% [markdown]
# **软体果冻 (Jelly)**
#
# 📂 [`./dependencies/mujoco/model/flex/jelly.xml`](./dependencies/mujoco/model/flex/jelly.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/flex/jelly.xml

# %% [markdown]
# **蹦床 (Trampoline)**
#
# 📂 [`./dependencies/mujoco/model/flex/trampoline.xml`](./dependencies/mujoco/model/flex/trampoline.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/flex/trampoline.xml

# %% [markdown]
# **软体兔子 (Bunny)**
#
# 📂 [`./dependencies/mujoco/model/flex/bunny.xml`](./dependencies/mujoco/model/flex/bunny.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/flex/bunny.xml

# %% [markdown]
# ### 🎲 物理互动与接触 (Interactions)
#
# **纸牌屋 (Cards)**
# *展示复杂的接触动力学*
#
# 📂 [`./dependencies/mujoco/model/cards/cards.xml`](./dependencies/mujoco/model/cards/cards.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/cards/cards.xml

# %% [markdown]
# **易碎杯子 (Mug)**
# *展示复合物体与碰撞*
#
# 📂 [`./dependencies/mujoco/model/mug/mug.xml`](./dependencies/mujoco/model/mug/mug.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/mug/mug.xml

# %% [markdown]
# **3x3x3 魔方 (Cube)**
#
# 📂 [`./dependencies/mujoco/model/cube/cube_3x3x3.xml`](./dependencies/mujoco/model/cube/cube_3x3x3.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/cube/cube_3x3x3.xml

# %% [markdown]
# **吊床 (Hammock)**
#
# 📂 [`./dependencies/mujoco/model/hammock/hammock.xml`](./dependencies/mujoco/model/hammock/hammock.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/hammock/hammock.xml

# %% [markdown]
# ### ⚙️ 经典物理演示 (Physics Demos)
#
# **牛顿摆 (Newton's Cradle)**
#
# 📂 [`./dependencies/mujoco/model/replicate/newton_cradle.xml`](./dependencies/mujoco/model/replicate/newton_cradle.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/replicate/newton_cradle.xml

# %% [markdown]
# **多米诺骨牌 (Dominos)**
#
# 📂 [`./dependencies/mujoco/model/sleep/dominos.xml`](./dependencies/mujoco/model/sleep/dominos.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/sleep/dominos.xml

# %% [markdown]
# **气球 (Balloons)**
#
# 📂 [`./dependencies/mujoco/model/balloons/balloons.xml`](./dependencies/mujoco/model/balloons/balloons.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/balloons/balloons.xml

# %% [markdown]
# **粒子系统 (Particles)**
#
# 📂 [`./dependencies/mujoco/model/replicate/particle.xml`](./dependencies/mujoco/model/replicate/particle.xml)

# %%
# !./build/bin/simulate ./dependencies/mujoco/model/replicate/particle.xml

# %% [markdown]
# ### 进阶：强化学习推理
#
# 如果你想运行训练好的强化学习策略（如 RL 训练出的走路策略），通常需要：
# 1. **策略文件**: 一个训练好的神经网络权重文件（如 `.pt` 或 `.onnx`）。
# 2. **推理代码**: 加载权重，获取 MuJoCo 的观测 (`data.qpos`, `data.qvel`, `data.sensordata`)，输入网络，获取动作，赋值给 `data.ctrl`。
#
# MuJoCo 官方提供了 **[MJM (MuJoCo MPC)](https://github.com/google-deepmind/mujoco_mpc)** 和 **[MJX (MuJoCo XLA)](https://github.com/google-deepmind/mujoco/tree/main/mjx)** 用于高级控制和学习。
