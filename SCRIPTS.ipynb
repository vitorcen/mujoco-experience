# %% [markdown]
# # SCRIPTS.md - 脚本运行指南
#
# 本目录 `scripts/` 包含用于演示、测试和控制 MuJoCo 仿真的 Python 脚本。
#
# > **提示**：运行前请确保已激活环境并更新子模块：
# >
# > ```bash
# > conda activate mujoco
# > git submodule update --init --recursive
# > ```
#
# ---
#
# > **Unitree 机器人仿真**: 详见 [UNITREE.md](./UNITREE.md)
#
# ---
#
# ## 1. 🤖 AI & VLA 策略 (AI Policies)
#
# 本节展示结合视觉语言模型 (VLA)、Transformer (ACT) 和扩散模型 (Diffusion) 的高级控制策略。
#
# ### 四足机器人 VLA 导航
#
# **脚本**: `scripts/quadruped_vla_demo.py`
# 演示使用 OpenVLA 视觉模型指挥 Unitree Go2 机器狗走向红球（跨形态控制）。

# %%
# 四足机器人 VLA 导航
# !python -u scripts/quadruped_vla_demo.py

# %% [markdown]
# ### 人形机器人 ACT 策略
#
# **脚本**: `scripts/humanoid_act_demo.py`
# 演示 ACT (Action Chunking with Transformers) 策略控制 Unitree G1。

# %%
# 人形机器人 ACT 策略
# !python -u scripts/humanoid_act_demo.py

# %% [markdown]
# ### 人形机器人 Diffusion Policy
#
# **脚本**: `scripts/humanoid_diffusion_demo.py`
# 演示 Diffusion Policy 策略控制 Unitree G1。

# %%
# 人形机器人 Diffusion Policy
# !python -u scripts/humanoid_diffusion_demo.py

# %% [markdown]
# ### VLA 机械臂推理
#
# **脚本**: `scripts/vla_inference_demo.py`
# 演示 OpenVLA 控制机械臂的完整流程。

# %%
# VLA 机械臂推理
# !python -u scripts/vla_inference_demo.py

# %% [markdown]
# ---
#
# ## 2. 🏃 人形机器人 MoCap (DeepMimic)
#
# 本节演示使用 **DeepMimic** 动作捕捉数据驱动人形机器人（直接运行即可预览）。
#
# **基础运动 (Walk, Run, Spinkick)**:

# %%
# 行走 (Walk)
# !python -u scripts/humanoid_walk_demo.py

# %%
# 跑步 (Run)
# !python -u scripts/humanoid_run_demo.py

# %%
# 回旋踢 (Spinkick)
# !python -u scripts/humanoid_spinkick_demo.py

# %% [markdown]
# **特技与恢复 (Dance, Backflip, Getup)**:

# %%
# 街舞 (Dance B)
# !python -u scripts/humanoid_dance_b_demo.py
# Out:
# Loading motion file: /home/david/work/mujoco-experience/DeepMimic_mujoco/src/mujoco/motions/humanoid3d_dance_b.txt
# ✅ Loaded 153 frames (dt≈0.016666s, total≈2.550s)
# Playing Dance B motion (153 frames)...

# %%
# 后空翻 (Backflip)
# !python -u scripts/humanoid_backflip_demo.py

# %%
# 跌倒爬起 (Stand Up - Faceup & Facedown)
# !python -u scripts/humanoid_getup_demo.py

# %% [markdown]
# ---
#
# ## 3. 🦾 机械臂操作 (Manipulation)
#
# ### Franka Panda 抓取 (IK Control)
#
# **脚本**: `scripts/panda_ik_demo.py`
# 使用差分逆运动学 (Differential IK) 控制 Panda 机械臂抓取物体。

# %%
# Franka Panda 抓取 (IK Control)
# !python -u scripts/panda_ik_demo.py
# Out:
# Loading model: scripts/panda_manipulation.xml
# Warning: Site 'attachment_site' not found, trying to find 'hand' body...
# Starting IK control loop...
# Robot will try to hover over the red box.

# %% [markdown]
# ### 基础关节控制
#
# 简单的关节空间控制演示。

# %%
# Franka Panda 简单控制
# !python -u scripts/panda_demo.py
# Out:
# Loading Panda model: ./mujoco_menagerie/franka_emika_panda/scene.xml

# %%
# Franka FR3 控制
# !python -u scripts/fr3_demo.py
# Out:
# Loading FR3 model: ./mujoco_menagerie/franka_fr3/scene.xml

# %%
# UR10e 机械臂控制
# !python -u scripts/ur10e_demo.py
# Out:
# Loading UR10e model: ./mujoco_menagerie/universal_robots_ur10e/scene.xml
# Xlib:  extension "NV-GLX" missing on display ":0".

# %% [markdown]
# ---
#
# ## 4. 🐕 四足机器人 (Quadruped)
#
# ### Go2 崎岖地形行走
#
# **脚本**: `scripts/go2_terrain_demo.py`
# 演示 Unitree Go2 在复杂地形（台阶、障碍）上的行走。

# %%
# Go2 崎岖地形行走
# !python -u scripts/go2_terrain_demo.py
# Out:
# Loading Go2 Terrain Scene...
# Starting simulation... (Go2 walking on rough terrain)

# %%
# Go2 崎岖地形行走 (Headless)
# !python -u scripts/go2_terrain_demo.py --headless --duration 20
# Out:
# Loading Go2 Terrain Scene...
# Starting simulation... (Go2 walking on rough terrain)
# [t=  0.00s] base_xyz = [1.19147052e-22 3.75381309e-23 3.49960760e-01]
# [t=  0.50s] base_xyz = [-0.02098861 -0.02625674  0.08045871]
# [t=  1.00s] base_xyz = [-0.02161616 -0.0202446   0.0786841 ]
# [t=  1.50s] base_xyz = [-0.02213563 -0.01558886  0.07707429]
# [t=  2.00s] base_xyz = [-0.02213518 -0.01553879  0.07707973]
# [t=  2.50s] base_xyz = [-0.02213511 -0.0155411   0.07707985]
# [t=  3.00s] base_xyz = [-0.02213525 -0.01553861  0.07707973]
# [t=  3.50s] base_xyz = [-0.02213519 -0.01554043  0.07707983]
# [t=  4.00s] base_xyz = [-0.0221352  -0.0155389   0.07707974]
# [t=  4.50s] base_xyz = [-0.02213514 -0.01554111  0.07707985]
# [t=  5.00s] base_xyz = [-0.02213528 -0.01553862  0.07707973]
# [t=  5.50s] base_xyz = [-0.02213522 -0.01554044  0.07707983]
# [t=  6.00s] base_xyz = [-0.02213523 -0.01553891  0.07707974]
# [t=  6.50s] base_xyz = [-0.02213516 -0.01554112  0.07707985]
# [t=  7.00s] base_xyz = [-0.0221353  -0.01553863  0.07707973]
# [t=  7.50s] base_xyz = [-0.02213524 -0.01554045  0.07707983]
# [t=  8.00s] base_xyz = [-0.02213525 -0.01553892  0.07707974]
# [t=  8.50s] base_xyz = [-0.02213519 -0.01554113  0.07707985]
# [t=  9.00s] base_xyz = [-0.02213533 -0.01553864  0.07707973]
# [t=  9.50s] base_xyz = [-0.02213527 -0.01554046  0.07707983]
# [t= 10.00s] base_xyz = [-0.02213528 -0.01553883  0.07707973]
# [t= 10.50s] base_xyz = [-0.02213521 -0.01554115  0.07707985]
# [t= 11.00s] base_xyz = [-0.02213535 -0.01553857  0.07707973]
# [t= 11.50s] base_xyz = [-0.02213529 -0.01554048  0.07707983]
# [t= 12.00s] base_xyz = [-0.02213531 -0.01553884  0.07707973]
# [t= 12.50s] base_xyz = [-0.02213524 -0.01554116  0.07707985]
# [t= 13.00s] base_xyz = [-0.02213538 -0.01553858  0.07707973]
# [t= 13.50s] base_xyz = [-0.02213532 -0.01554049  0.07707983]
# [t= 14.00s] base_xyz = [-0.02213533 -0.01553885  0.07707973]
# [t= 14.50s] base_xyz = [-0.02213526 -0.01554117  0.07707985]
# [t= 15.00s] base_xyz = [-0.0221354  -0.01553859  0.07707973]
# [t= 15.50s] base_xyz = [-0.02213535 -0.0155405   0.07707983]
# [t= 16.00s] base_xyz = [-0.02213536 -0.01553886  0.07707973]
# [t= 16.50s] base_xyz = [-0.02213529 -0.01554118  0.07707985]
# [t= 17.00s] base_xyz = [-0.02213543 -0.0155386   0.07707973]
# [t= 17.50s] base_xyz = [-0.02213537 -0.01554051  0.07707983]
# [t= 18.00s] base_xyz = [-0.02213538 -0.01553887  0.07707973]
# [t= 18.50s] base_xyz = [-0.02213531 -0.01554119  0.07707985]
# [t= 19.00s] base_xyz = [-0.02213545 -0.01553861  0.07707973]
# [t= 19.50s] base_xyz = [-0.0221354  -0.01554052  0.07707983]
# [t= 20.00s] base_xyz = [-0.02213541 -0.01553897  0.07707974]
# Headless simulation finished.
# 如果你需要可视化：请在有桌面 OpenGL/GLX 的环境运行，或用录屏/离屏渲染方案。

# %% [markdown]
# ### Boston Dynamics Spot
#
# **脚本**: `scripts/spot_demo.py`
# 控制 Spot 机器狗进行基础动作演示。

# %%
# Boston Dynamics Spot
# !python -u scripts/spot_demo.py
# Out:
# Loading Spot model: ./mujoco_menagerie/boston_dynamics_spot/scene.xml

# %% [markdown]
# ---
#
# ## 5. 🚁 其他机器人 (Other Robots)
#
# ### Agility Robotics Cassie
#
# **脚本**: `scripts/cassie_demo.py`
# 控制 Cassie 双足机器人。

# %%
# Agility Robotics Cassie
# !python -u scripts/cassie_demo.py
# Out:
# Loading Cassie model: ./mujoco_menagerie/agility_cassie/scene.xml

# %% [markdown]
# ### Bitcraze Crazyflie 2
#
# **脚本**: `scripts/crazyflie_demo.py`
# 控制微型四旋翼无人机。

# %%
# Bitcraze Crazyflie 2
# !python -u scripts/crazyflie_demo.py
# Out:
# Loading Crazyflie model: ./mujoco_menagerie/bitcraze_crazyflie_2/scene.xml
